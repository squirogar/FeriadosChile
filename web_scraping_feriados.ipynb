# %%
import requests
from bs4 import BeautifulSoup

# %%
URL_BASE = "https://feriados.cl/"

request_response = requests.get(URL_BASE)

# %%
# a string
html_feriados = request_response.text

# %%
# parseamos el html
soup = BeautifulSoup(html_feriados, "html.parser")

# %%
# obtenemos la primera tabla
tabla = soup.find("table")
tabla
# Out:
# <table>
# <tr>
# <td colspan="4">
# <!-- BloqueResponsivo -->
# <div class="ads"><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-1764294017474123" data-ad-format="auto" data-ad-slot="5711300468" style="display:block"></ins>
# <script>
# 			(adsbygoogle = window.adsbygoogle || []).push({});
# 			</script>
# </div>
# </td>
# </tr>
# <tr>
# <td class="subtabla" colspan="4"> Feriados de carácter general
# 			<span style="font-style:italic; font-weight: normal;">(Aplican a todas las personas a nivel nacional)</span></td>
# </tr>
# <tr style="background-color:#004080;">
# <th>Día</th>
# <th>Festividad</th>
# <th>Tipo</th>
# <th class="rl">Respaldo Legal</th>
# </tr>
# <tr>
# <td>Todos los Días Domingos</td>
# <td>Día Domingo</td>
# <td>Civil</td>
# <td class="rl">Ley 2.977</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Lunes, 01 de Enero</td>
# <td>Año Nuevo<br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></td>
# <td>Civil</td>
# <td class="rl">Ley 2.977,
# 			Ley 19.973</td>
# </tr>
# <tr> <td>Viernes, 29 de Marzo</td>
# <td>Viernes Santo</td>
# <td>Religioso</td>
# <td class="rl">Ley 2.977</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Sábado, 30 de Marzo</td>
# <td>Sábado Santo</td>
# <td>Religioso</td>
# <td class="rl">Ley 2.977</td>
# </tr>
# <tr> <td>Miércoles, 01 de Mayo</td>
# <td>Día Nacional del Trabajo<br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></td>
# <td>Civil</td>
# <td class="rl">Código del Trabajo,
# 			Ley 19.973</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Martes, 21 de Mayo</td>
# <td>Día de las Glorias Navales</td>
# <td>Civil</td>
# <td class="rl">Ley 2.977</td>
# </tr>
# <tr> <td>Domingo, 09 de Junio</td>
# <td>Elecciones Primarias Alcaldes y Gobernadores<br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></td>
# <td>Civil</td>
# <td class="rl">Ley 18.700, Ley 19.973</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Jueves, 20 de Junio</td>
# <td>Día Nacional de los Pueblos Indígenas</td>
# <td>Civil</td>
# <td class="rl">Ley 21.357</td>
# </tr>
# <tr> <td>Sábado, 29 de Junio</td>
# <td>San Pedro y San Pablo</td>
# <td>Religioso</td>
# <td class="rl">Ley 2.977,
# 			Ley 18.432,
# 			Ley 19.668</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Martes, 16 de Julio</td>
# <td>Día de la Virgen del Carmen</td>
# <td>Religioso</td>
# <td class="rl">Ley 20.148</td>
# </tr>
# <tr> <td>Jueves, 15 de Agosto</td>
# <td>Asunción de la Virgen</td>
# <td>Religioso</td>
# <td class="rl">Ley 2.977</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Miércoles, 18 de Septiembre</td>
# <td>Independencia Nacional<br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></td>
# <td>Civil</td>
# <td class="rl">Ley 2.977,
# 			Ley 19.973</td>
# </tr>
# <tr> <td>Jueves, 19 de Septiembre</td>
# <td>Día de las Glorias del Ejército<br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></td>
# <td>Civil</td>
# <td class="rl">Ley 2.977,
# 			Ley 20.629</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Viernes, 20 de Septiembre</td>
# <td>Feriado Adicional Fiestas Patrias</td>
# <td>Civil</td>
# <td class="rl">Ley 20.215</td>
# </tr>
# <tr> <td>Sábado, 12 de Octubre</td>
# <td>Encuentro de Dos Mundos</td>
# <td>Civil</td>
# <td class="rl">Ley 3.810,
# 			Ley 19.668</td>
# </tr>
# <tr style="background-color: #F6CECE;"> <td>Domingo, 27 de Octubre</td>
# <td>Elecciones Municipales, Consejeros Regionales y Gobernadores Regionales<br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></td>
# <td>Civil</td>
# <td class="rl">Ley 18.700, Ley 19.973</td>
# </tr>
# <tr> <td>Jueves, 31 de Octubre</td>
# <td>Día de las Iglesias Evangélicas y<br/>Protestantes</td>
# <td>Religioso</td>
# <td class="rl">Ley 20.299</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Viernes, 01 de Noviembre</td>
# <td>Día de Todos los Santos</td>
# <td>Religioso</td>
# <td class="rl">Ley 2.977</td>
# </tr>
# <tr> <td>Domingo, 24 de Noviembre</td>
# <td>Segunda Vuelta Elección Gobernadores Regionales<br>
# <span style="font-style:italic;">Por Confirmar</span><br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></br></td>
# <td>Civil</td>
# <td class="rl">Ley 18.700, Ley 19.973</td>
# </tr>
# <tr style="background-color: #e7e7ff;"> <td>Domingo, 08 de Diciembre</td>
# <td>Inmaculada Concepción</td>
# <td>Religioso</td>
# <td class="rl">Ley 2.977</td>
# </tr>
# <tr> <td>Miércoles, 25 de Diciembre</td>
# <td>Navidad<br/>
# <span style="color: #ff0000; font-style:italic;">Irrenunciable</span></td>
# <td>Religioso</td>
# <td class="rl">Ley 2.977,
# 			Ley 19.973</td>
# </tr>
# </table>

# %%
# eliminamos todos los elementos con la clase "rl"
# estos elementos contienen las leyes, lo que no
# nos interesa
for element in tabla.find_all(class_="rl"):
    element.decompose()

# %%
for element in tabla.find_all("span"):
    element.decompose()

# %%
# obtenemos todos los tr
rows = tabla.find_all("tr")
print(rows)
# Out:
# [<tr>
# <td colspan="4">
# <!-- BloqueResponsivo -->
# <div class="ads"><script async="" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
# <ins class="adsbygoogle" data-ad-client="ca-pub-1764294017474123" data-ad-format="auto" data-ad-slot="5711300468" style="display:block"></ins>
# <script>
# 			(adsbygoogle = window.adsbygoogle || []).push({});
# 			</script>
# </div>
# </td>
# </tr>, <tr>
# <td class="subtabla" colspan="4"> Feriados de carácter general
# 			</td>
# </tr>, <tr style="background-color:#004080;">
# <th>Día</th>
# <th>Festividad</th>
# <th>Tipo</th>
#
# </tr>, <tr>
# <td>Todos los Días Domingos</td>
# <td>Día Domingo</td>
# <td>Civil</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Lunes, 01 de Enero</td>
# <td>Año Nuevo<br/>
# </td>
# <td>Civil</td>
#
# </tr>, <tr> <td>Viernes, 29 de Marzo</td>
# <td>Viernes Santo</td>
# <td>Religioso</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Sábado, 30 de Marzo</td>
# <td>Sábado Santo</td>
# <td>Religioso</td>
#
# </tr>, <tr> <td>Miércoles, 01 de Mayo</td>
# <td>Día Nacional del Trabajo<br/>
# </td>
# <td>Civil</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Martes, 21 de Mayo</td>
# <td>Día de las Glorias Navales</td>
# <td>Civil</td>
#
# </tr>, <tr> <td>Domingo, 09 de Junio</td>
# <td>Elecciones Primarias Alcaldes y Gobernadores<br/>
# </td>
# <td>Civil</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Jueves, 20 de Junio</td>
# <td>Día Nacional de los Pueblos Indígenas</td>
# <td>Civil</td>
#
# </tr>, <tr> <td>Sábado, 29 de Junio</td>
# <td>San Pedro y San Pablo</td>
# <td>Religioso</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Martes, 16 de Julio</td>
# <td>Día de la Virgen del Carmen</td>
# <td>Religioso</td>
#
# </tr>, <tr> <td>Jueves, 15 de Agosto</td>
# <td>Asunción de la Virgen</td>
# <td>Religioso</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Miércoles, 18 de Septiembre</td>
# <td>Independencia Nacional<br/>
# </td>
# <td>Civil</td>
#
# </tr>, <tr> <td>Jueves, 19 de Septiembre</td>
# <td>Día de las Glorias del Ejército<br/>
# </td>
# <td>Civil</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Viernes, 20 de Septiembre</td>
# <td>Feriado Adicional Fiestas Patrias</td>
# <td>Civil</td>
#
# </tr>, <tr> <td>Sábado, 12 de Octubre</td>
# <td>Encuentro de Dos Mundos</td>
# <td>Civil</td>
#
# </tr>, <tr style="background-color: #F6CECE;"> <td>Domingo, 27 de Octubre</td>
# <td>Elecciones Municipales, Consejeros Regionales y Gobernadores Regionales<br/>
# </td>
# <td>Civil</td>
#
# </tr>, <tr> <td>Jueves, 31 de Octubre</td>
# <td>Día de las Iglesias Evangélicas y<br/>Protestantes</td>
# <td>Religioso</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Viernes, 01 de Noviembre</td>
# <td>Día de Todos los Santos</td>
# <td>Religioso</td>
#
# </tr>, <tr> <td>Domingo, 24 de Noviembre</td>
# <td>Segunda Vuelta Elección Gobernadores Regionales<br>
# <br/>
# </br></td>
# <td>Civil</td>
#
# </tr>, <tr style="background-color: #e7e7ff;"> <td>Domingo, 08 de Diciembre</td>
# <td>Inmaculada Concepción</td>
# <td>Religioso</td>
#
# </tr>, <tr> <td>Miércoles, 25 de Diciembre</td>
# <td>Navidad<br/>
# </td>
# <td>Religioso</td>
#
# </tr>]

# %%
# no nos sirve la fila 0, 1, 2 y 3
feriados_rows = rows[4:]
# feriados_rows

# %%
feriados_rows
# Out:
# [<tr style="background-color: #e7e7ff;"> <td>Lunes, 01 de Enero</td>
#  <td>Año Nuevo<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>Viernes, 29 de Marzo</td>
#  <td>Viernes Santo</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Sábado, 30 de Marzo</td>
#  <td>Sábado Santo</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>Miércoles, 01 de Mayo</td>
#  <td>Día Nacional del Trabajo<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Martes, 21 de Mayo</td>
#  <td>Día de las Glorias Navales</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>Domingo, 09 de Junio</td>
#  <td>Elecciones Primarias Alcaldes y Gobernadores<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Jueves, 20 de Junio</td>
#  <td>Día Nacional de los Pueblos Indígenas</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>Sábado, 29 de Junio</td>
#  <td>San Pedro y San Pablo</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Martes, 16 de Julio</td>
#  <td>Día de la Virgen del Carmen</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>Jueves, 15 de Agosto</td>
#  <td>Asunción de la Virgen</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Miércoles, 18 de Septiembre</td>
#  <td>Independencia Nacional<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>Jueves, 19 de Septiembre</td>
#  <td>Día de las Glorias del Ejército<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Viernes, 20 de Septiembre</td>
#  <td>Feriado Adicional Fiestas Patrias</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>Sábado, 12 de Octubre</td>
#  <td>Encuentro de Dos Mundos</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #F6CECE;"> <td>Domingo, 27 de Octubre</td>
#  <td>Elecciones Municipales, Consejeros Regionales y Gobernadores Regionales<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>Jueves, 31 de Octubre</td>
#  <td>Día de las Iglesias Evangélicas y<br/>Protestantes</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Viernes, 01 de Noviembre</td>
#  <td>Día de Todos los Santos</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>Domingo, 24 de Noviembre</td>
#  <td>Segunda Vuelta Elección Gobernadores Regionales<br>
#  <br/>
#  </br></td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>Domingo, 08 de Diciembre</td>
#  <td>Inmaculada Concepción</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>Miércoles, 25 de Diciembre</td>
#  <td>Navidad<br/>
#  </td>
#  <td>Religioso</td>
#
#  </tr>]

# %%
MONTHS = [
    "Enero", "Febrero", "Marzo", "Abril", "Mayo",
    "Junio", "Julio", "Agosto", "Septiembre",
    "Octubre", "Noviembre", "Diciembre"]

YEAR = "2024"

for feriado in feriados_rows:
    fecha = feriado.find("td")
    # print(fecha)
    # [nombre_dia, numero_dia, "de", nombre_mes]
    valores = fecha.get_text().split(" ")
    # print(valores)
    # buscamos que numero_mes es de acuerdo al nombre_mes
    numero_mes = MONTHS.index(valores[-1]) + 1
    # print(numero_mes)
    fecha.string.replace_with(f"{YEAR}-{numero_mes}-{valores[1]}")
    # print(fecha)

# %%
feriados_rows
# Out:
# [<tr style="background-color: #e7e7ff;"> <td>2024-1-01</td>
#  <td>Año Nuevo<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>2024-3-29</td>
#  <td>Viernes Santo</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-3-30</td>
#  <td>Sábado Santo</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>2024-5-01</td>
#  <td>Día Nacional del Trabajo<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-5-21</td>
#  <td>Día de las Glorias Navales</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>2024-6-09</td>
#  <td>Elecciones Primarias Alcaldes y Gobernadores<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-6-20</td>
#  <td>Día Nacional de los Pueblos Indígenas</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>2024-6-29</td>
#  <td>San Pedro y San Pablo</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-7-16</td>
#  <td>Día de la Virgen del Carmen</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>2024-8-15</td>
#  <td>Asunción de la Virgen</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-9-18</td>
#  <td>Independencia Nacional<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>2024-9-19</td>
#  <td>Día de las Glorias del Ejército<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-9-20</td>
#  <td>Feriado Adicional Fiestas Patrias</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>2024-10-12</td>
#  <td>Encuentro de Dos Mundos</td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #F6CECE;"> <td>2024-10-27</td>
#  <td>Elecciones Municipales, Consejeros Regionales y Gobernadores Regionales<br/>
#  </td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr> <td>2024-10-31</td>
#  <td>Día de las Iglesias Evangélicas y<br/>Protestantes</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-11-01</td>
#  <td>Día de Todos los Santos</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>2024-11-24</td>
#  <td>Segunda Vuelta Elección Gobernadores Regionales<br>
#  <br/>
#  </br></td>
#  <td>Civil</td>
#
#  </tr>,
#  <tr style="background-color: #e7e7ff;"> <td>2024-12-08</td>
#  <td>Inmaculada Concepción</td>
#  <td>Religioso</td>
#
#  </tr>,
#  <tr> <td>2024-12-25</td>
#  <td>Navidad<br/>
#  </td>
#  <td>Religioso</td>
#
#  </tr>]

# %%
lista_feriados = []

for f in feriados_rows:
    tds = f.find_all("td")

    datos = []
    for dato in tds:
        datos.append(dato.get_text(strip=True))

    lista_feriados.append(datos)

# %%
lista_feriados
# Out:
# [['2024-1-01', 'Año Nuevo', 'Civil'],
#  ['2024-3-29', 'Viernes Santo', 'Religioso'],
#  ['2024-3-30', 'Sábado Santo', 'Religioso'],
#  ['2024-5-01', 'Día Nacional del Trabajo', 'Civil'],
#  ['2024-5-21', 'Día de las Glorias Navales', 'Civil'],
#  ['2024-6-09', 'Elecciones Primarias Alcaldes y Gobernadores', 'Civil'],
#  ['2024-6-20', 'Día Nacional de los Pueblos Indígenas', 'Civil'],
#  ['2024-6-29', 'San Pedro y San Pablo', 'Religioso'],
#  ['2024-7-16', 'Día de la Virgen del Carmen', 'Religioso'],
#  ['2024-8-15', 'Asunción de la Virgen', 'Religioso'],
#  ['2024-9-18', 'Independencia Nacional', 'Civil'],
#  ['2024-9-19', 'Día de las Glorias del Ejército', 'Civil'],
#  ['2024-9-20', 'Feriado Adicional Fiestas Patrias', 'Civil'],
#  ['2024-10-12', 'Encuentro de Dos Mundos', 'Civil'],
#  ['2024-10-27',
#   'Elecciones Municipales, Consejeros Regionales y Gobernadores Regionales',
#   'Civil'],
#  ['2024-10-31', 'Día de las Iglesias Evangélicas yProtestantes', 'Religioso'],
#  ['2024-11-01', 'Día de Todos los Santos', 'Religioso'],
#  ['2024-11-24', 'Segunda Vuelta Elección Gobernadores Regionales', 'Civil'],
#  ['2024-12-08', 'Inmaculada Concepción', 'Religioso'],
#  ['2024-12-25', 'Navidad', 'Religioso']]

# %%
# guardamos los datos en un csv
import csv

lista_feriados.insert(0, ["fecha","motivo","tipo"])
NOMBRE_ARCHIVO = "feriados.csv"

# escribimos los feriados en un archivo csv

with open(NOMBRE_ARCHIVO, "w") as archivo:
    escritor_csv = csv.writer(archivo)

    # escribimos cada feriado en una nueva línea
    for feriado in lista_feriados:
        print(feriado)
        escritor_csv.writerow(feriado)
# Out:
# ['fecha', 'motivo', 'tipo']
# ['2024-1-01', 'Año Nuevo', 'Civil']
# ['2024-3-29', 'Viernes Santo', 'Religioso']
# ['2024-3-30', 'Sábado Santo', 'Religioso']
# ['2024-5-01', 'Día Nacional del Trabajo', 'Civil']
# ['2024-5-21', 'Día de las Glorias Navales', 'Civil']
# ['2024-6-09', 'Elecciones Primarias Alcaldes y Gobernadores', 'Civil']
# ['2024-6-20', 'Día Nacional de los Pueblos Indígenas', 'Civil']
# ['2024-6-29', 'San Pedro y San Pablo', 'Religioso']
# ['2024-7-16', 'Día de la Virgen del Carmen', 'Religioso']
# ['2024-8-15', 'Asunción de la Virgen', 'Religioso']
# ['2024-9-18', 'Independencia Nacional', 'Civil']
# ['2024-9-19', 'Día de las Glorias del Ejército', 'Civil']
# ['2024-9-20', 'Feriado Adicional Fiestas Patrias', 'Civil']
# ['2024-10-12', 'Encuentro de Dos Mundos', 'Civil']
# ['2024-10-27', 'Elecciones Municipales, Consejeros Regionales y Gobernadores Regionales', 'Civil']
# ['2024-10-31', 'Día de las Iglesias Evangélicas yProtestantes', 'Religioso']
# ['2024-11-01', 'Día de Todos los Santos', 'Religioso']
# ['2024-11-24', 'Segunda Vuelta Elección Gobernadores Regionales', 'Civil']
# ['2024-12-08', 'Inmaculada Concepción', 'Religioso']
# ['2024-12-25', 'Navidad', 'Religioso']
